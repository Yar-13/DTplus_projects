# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Первичное-ознакомление-с-данными." data-toc-modified-id="Первичное-ознакомление-с-данными.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Первичное ознакомление с данными.</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Исследовательский-анализ-данных." data-toc-modified-id="Исследовательский-анализ-данных.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных.</a></span><ul class="toc-item"><li><span><a href="#market_file" data-toc-modified-id="market_file-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>market_file</a></span><ul class="toc-item"><li><span><a href="#market_active_6_month" data-toc-modified-id="market_active_6_month-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>market_active_6_month</a></span></li><li><span><a href="#market_active_current_month" data-toc-modified-id="market_active_current_month-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>market_active_current_month</a></span></li><li><span><a href="#duration" data-toc-modified-id="duration-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>duration</a></span></li><li><span><a href="#promotional_purchases" data-toc-modified-id="promotional_purchases-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>promotional_purchases</a></span></li><li><span><a href="#mean_views_category_per_visit" data-toc-modified-id="mean_views_category_per_visit-5.1.5"><span class="toc-item-num">5.1.5&nbsp;&nbsp;</span>mean_views_category_per_visit</a></span></li><li><span><a href="#unpaid_product_cvart" data-toc-modified-id="unpaid_product_cvart-5.1.6"><span class="toc-item-num">5.1.6&nbsp;&nbsp;</span>unpaid_product_cvart</a></span></li><li><span><a href="#service_error" data-toc-modified-id="service_error-5.1.7"><span class="toc-item-num">5.1.7&nbsp;&nbsp;</span>service_error</a></span></li><li><span><a href="#page_per_visit" data-toc-modified-id="page_per_visit-5.1.8"><span class="toc-item-num">5.1.8&nbsp;&nbsp;</span>page_per_visit</a></span></li><li><span><a href="#buying_activity" data-toc-modified-id="buying_activity-5.1.9"><span class="toc-item-num">5.1.9&nbsp;&nbsp;</span>buying_activity</a></span></li><li><span><a href="#type_service" data-toc-modified-id="type_service-5.1.10"><span class="toc-item-num">5.1.10&nbsp;&nbsp;</span>type_service</a></span></li><li><span><a href="#allow_reporting" data-toc-modified-id="allow_reporting-5.1.11"><span class="toc-item-num">5.1.11&nbsp;&nbsp;</span>allow_reporting</a></span></li><li><span><a href="#popular_category" data-toc-modified-id="popular_category-5.1.12"><span class="toc-item-num">5.1.12&nbsp;&nbsp;</span>popular_category</a></span></li></ul></li><li><span><a href="#market_money" data-toc-modified-id="market_money-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>market_money</a></span><ul class="toc-item"><li><span><a href="#revenue" data-toc-modified-id="revenue-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>revenue</a></span></li><li><span><a href="#period" data-toc-modified-id="period-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>period</a></span></li></ul></li><li><span><a href="#market_time" data-toc-modified-id="market_time-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>market_time</a></span><ul class="toc-item"><li><span><a href="#min" data-toc-modified-id="min-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>min</a></span></li><li><span><a href="#period" data-toc-modified-id="period-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>period</a></span></li></ul></li><li><span><a href="#money" data-toc-modified-id="money-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>money</a></span><ul class="toc-item"><li><span><a href="#profit" data-toc-modified-id="profit-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>profit</a></span></li></ul></li><li><span><a href="#Отбор-клиентов-с-покупательской-активностью-не-менее-трёх-месяцев" data-toc-modified-id="Отбор-клиентов-с-покупательской-активностью-не-менее-трёх-месяцев-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Отбор клиентов с покупательской активностью не менее трёх месяцев</a></span></li></ul></li><li><span><a href="#Объединение-таблиц" data-toc-modified-id="Объединение-таблиц-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Объединение таблиц</a></span></li><li><span><a href="#корреляционный-анализ-признаков-в-датасете-df" data-toc-modified-id="корреляционный-анализ-признаков-в-датасете-df-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>корреляционный анализ признаков в датасете df</a></span></li><li><span><a href="#Применение-пайплайнов" data-toc-modified-id="Применение-пайплайнов-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Применение пайплайнов</a></span></li><li><span><a href="#Анализ-важности-признаков" data-toc-modified-id="Анализ-важности-признаков-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Анализ важности признаков</a></span></li><li><span><a href="#Сегментация-покупателей" data-toc-modified-id="Сегментация-покупателей-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Сегментация покупателей</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
#
# 1. Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# 2. В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# 3. Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#
# `market_file.csv`:
# - `id` — номер покупателя в корпоративной базе данных.
# - `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - `Тип сервиса` — уровень сервиса, например «премиум» и «стандарт».
# - `Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - `Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - `Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце.
# - `Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - `Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - `Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - `Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - `Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - `Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
# - `Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
#
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
#
# `market_money.csv`:
# - `id` — номер покупателя в корпоративной базе данных.
# - `Период` — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# - `Выручка` — сумма выручки за период.
#
#
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
#
# `market_time.csv`:
# - `id` — номер покупателя в корпоративной базе данных.
# - `Период` — название периода, во время которого зафиксировано общее время.
# - `минут` — значение времени, проведённого на сайте, в минутах.
#
#
# Таблица с данными о среднемесячной прибыли с покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
# `money.csv`:
# - `id` — номер покупателя в корпоративной базе данных.
# - `Прибыль` — значение прибыли.

# %% [markdown]
# ## Первичное ознакомление с данными.

# %%
# !pip install phik

# %%
# !pip install shap

# %%
# !pip install numpy --upgrade
# Out:
# ...
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.8.0 requires numpy<1.25.0,>=1.17.3, but you have numpy 2.0.2 which is incompatible.

# %%
# !pip install -q --upgrade scikit-learn
# !pip install -q --upgrade matplotlib
# !pip install -q --upgrade numba
# !pip install -q --upgrade shap
# !pip install -q --upgrade shap
# !pip install -q --upgrade seaborn

# %%
# убрать предупреждения
import warnings
warnings.filterwarnings('ignore')

# %%
# импорт необходимых библиотек.
import pandas as pd
import shap
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import phik

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, OrdinalEncoder, LabelEncoder, RobustScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score, recall_score, precision_score, confusion_matrix, roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import RandomizedSearchCV

# %%
# настроим точность вывода до 2-х десятичных знаков и разделители тысяч (групп разрядов) для больших чисел
pd.set_option('display.float_format', '{:,.2f}'.format)

# необходимо для показа всех столбцов.
pd.options.display.max_columns = None 

# установим графическую тему для графиков и гистограмм
plt.style.use('seaborn-v0_8')

# %%
# загрузка датафреймов.

try:
    df_mf = pd.read_csv('/datasets/market_file.csv')
    df_mm = pd.read_csv('/datasets/market_money.csv')
    df_mt = pd.read_csv('/datasets/market_time.csv')
    df_m = pd.read_csv('/datasets/money.csv', sep=';')
    
except Exception:
    df_mf = pd.read_csv('market_file.csv')
    df_mm = pd.read_csv('market_money.csv')
    df_mt = pd.read_csv('market_time.csv')
    df_m = pd.read_csv('money.csv', sep=';')

# %%
# обзор датасета df_mf
df_mf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
# переименуем столбцы на более корреткные названия
df_mf.columns = ['id', 'buying_activity', 'type_service', 'allow_reporting', 'market_active_6_month', 'market_active_current_month', 'duration', 'promotional_purchases', 'popular_category', 'mean_views_category_per_visit', 'unpaid_product_cvart', 'service_error', 'page_per_visit']
df_mf.head()
# Out:
#        id buying_activity type_service allow_reporting  market_active_6_month  \
# 0  215348       Снизилась      премиум              да                   3.40
# 1  215349       Снизилась      премиум              да                   4.40
# 2  215350       Снизилась    стандартт             нет                   4.90
# 3  215351       Снизилась    стандартт              да                   3.20
# 4  215352       Снизилась    стандартт             нет                   5.10
#
#    market_active_current_month  duration  promotional_purchases  \
# 0                            5       121                   0.00
# 1                            4       819                   0.75
# 2                            3       539                   0.14
# 3                            5       896                   0.99
# 4                            3      1064                   0.94
#
#     popular_category  mean_views_category_per_visit  unpaid_product_cvart  \
# ...

# %%
# обзор датасета df_mm
df_mm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
# переименуем столбцы на более корреткные названия
df_mm.columns = ['id', 'period', 'revenue']
df_mm.head()
# Out:
#        id               period  revenue
# 0  215348  препредыдущий_месяц     0.00
# 1  215348        текущий_месяц 3,293.10
# 2  215348     предыдущий_месяц     0.00
# 3  215349  препредыдущий_месяц 4,472.00
# 4  215349        текущий_месяц 4,971.60

# %%
# обзор датасета df_mt
df_mt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
# переименуем столбцы на более корреткные названия
df_mt.columns = ['id', 'period', 'min']
df_mt.head()
# Out:
#        id            period  min
# 0  215348     текущий_месяц   14
# 1  215348  предыдцщий_месяц   13
# 2  215349     текущий_месяц   10
# 3  215349  предыдцщий_месяц   12
# 4  215350     текущий_месяц   13

# %%
# обзор датасета df_m
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 20.4+ KB

# %%
# переименуем столбцы на более корреткные названия
df_m.columns = ['id', 'profit']
df_m.head()
# Out:
#        id profit
# 0  215348   0,98
# 1  215349   4,16
# 2  215350   3,13
# 3  215351   4,87
# 4  215352   4,21

# %% [markdown]
# **Промежуточный вывод:**
#
# По результатам ознакомления с данными стало известно, что в распоряжении имеется 4 датасета с различной информацией о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении; о выручке, которую получает магазин с покупателя; о времени (в минутах), которое покупатель провёл на сайте в течение периода; о среднемесячной прибыли покупателя за последние 3 месяца. Были переименованы столбцы для более удобной работы с датасетом.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# работа с датасетом `df_mf`.

# %%
df_mf.isna().sum()
# Out:
# id                               0
# buying_activity                  0
# type_service                     0
# allow_reporting                  0
# market_active_6_month            0
# market_active_current_month      0
# duration                         0
# promotional_purchases            0
# popular_category                 0
# mean_views_category_per_visit    0
# unpaid_product_cvart             0
# service_error                    0
# page_per_visit                   0
# dtype: int64

# %%
df_mf.duplicated().sum()
# Out:
# 0

# %%
display(df_mf['type_service'].unique())
df_mf.loc[df_mf['type_service'] == 'стандартт', 'type_service'] = 'стандарт'
df_mf['type_service'].unique()
# Out:
# array(['премиум', 'стандартт', 'стандарт'], dtype=object)
# array(['премиум', 'стандарт'], dtype=object)

# %% [markdown]
# работа с датасетом `df_mm`.

# %%
df_mm.isna().sum()
# Out:
# id         0
# period     0
# revenue    0
# dtype: int64

# %%
df_mm.duplicated().sum()
# Out:
# 0

# %% [markdown]
# работа с датасетом `df_mt`.

# %%
df_mt['period'].unique()
# Out:
# array(['текущий_месяц', 'предыдцщий_месяц'], dtype=object)

# %%
df_mt.isna().sum()
# Out:
# id        0
# period    0
# min       0
# dtype: int64

# %%
df_mt.duplicated().sum()
# Out:
# 0

# %%
df_mt.loc[df_mt['period'] == 'предыдцщий_месяц', 'period'] = 'предыдущий_месяц'
df_mt['period'].unique()
# Out:
# array(['текущий_месяц', 'предыдущий_месяц'], dtype=object)

# %% [markdown]
# работа с датасетом `df_m`.

# %%
df_m.isna().sum()
# Out:
# id        0
# profit    0
# dtype: int64

# %%
df_m.duplicated().sum()
# Out:
# 0

# %%
df_m['profit'] = df_m['profit'].agg(lambda x: re.sub(r',', r'.', x)).astype('float')
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      1300 non-null   int64
#  1   profit  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# **Промежуточный вывод:**
#
# По результатам предобработки данных была проведена работа по проверке данных на пропуски, по очистке данных от дубликатов, по преобразованию типов данных.

# %% [markdown]
# ## Исследовательский анализ данных.

# %% [markdown]
# ### market_file

# %%
df_mf.describe()
# Out:
#               id  market_active_6_month  market_active_current_month  \
# count   1,300.00               1,300.00                     1,300.00
# mean  215,997.50                   4.25                         4.01
# std       375.42                   1.01                         0.70
# min   215,348.00                   0.90                         3.00
# 25%   215,672.75                   3.70                         4.00
# 50%   215,997.50                   4.20                         4.00
# 75%   216,322.25                   4.90                         4.00
# max   216,647.00                   6.60                         5.00
#
#        duration  promotional_purchases  mean_views_category_per_visit  \
# count  1,300.00               1,300.00                       1,300.00
# mean     601.90                   0.32                           3.27
# std      249.86                   0.25                           1.36
# ...

# %%
df_mf.describe(include='object')
# Out:
#         buying_activity type_service allow_reporting  popular_category
# count              1300         1300            1300              1300
# unique                2            2               2                 6
# top     Прежний уровень     стандарт              да  Товары для детей
# freq                802          924             962               330

# %% [markdown]
# #### market_active_6_month

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.boxplot(df_mf['market_active_6_month'], vert=False)
ax.set(xlabel='маркетинговые коммуникации', ylabel='item', title='среднемесячное значение маркетинговых коммуникаций компании')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(df_mf['market_active_6_month'], bins=15, rwidth=0.8)

ax.set(xlabel='среднемесячное значение маркетинговых коммуникаций компании', ylabel='количество записей', title='Гистограмма распрделения среднемесячного значения маркетинговых коммуникаций компании')

plt.show()

# %% [markdown]
# #### market_active_current_month

# %%
_ = df_mf['market_active_current_month'].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(15,5))

ax.bar( _['index'], _['market_active_current_month'], tick_label=_['index'])

ax.set(xlabel='значение маркетинговых комуникаций', ylabel='количество записей', title='распределение количества маркетинговых коммуникаций в текущем месяце')

plt.show()

# %% [markdown]
# #### duration

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.boxplot(df_mf['duration'], vert=False)
ax.set(xlabel='количество дней с момента регистрации', ylabel='item', title='Значения количества дней с момента регистрации пользователя')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.hist(df_mf['duration'], bins=20, rwidth=0.8)
ax.set(xlabel='количество дней с момента регистрации', ylabel='количество записей', title='Гистограмма распределения количества дней с момента регистрации')

plt.show()

# %% [markdown]
# #### promotional_purchases

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.boxplot(df_mf['promotional_purchases'], vert=False)
ax.set(xlabel='среднемесячная доля покупок по акции от общего числа покупок', ylabel='item', title='среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.hist(df_mf['promotional_purchases'], bins=8, rwidth=0.8)
ax.set(xlabel='среднемесячная доля покупок по акции от общего числа покупок', ylabel='количество записей', title='Распределение среднемесячной доли покупок по акции от общего числа покупок за последние 6 месяцев')

plt.show()

# %% [markdown]
# #### mean_views_category_per_visit

# %%
_  = df_mf['mean_views_category_per_visit'].value_counts().reset_index()
fig, ax = plt.subplots(figsize=(15,5))

ax.bar(_['index'], _['mean_views_category_per_visit'], tick_label=_['index'])
ax.set(xlabel='срденее количество категорий', ylabel='количество записей', title='Распределение срденего количества категорий просмотреного за последний месяц')

plt.show()

# %% [markdown]
# #### unpaid_product_cvart

# %%
_  = df_mf['unpaid_product_cvart'].value_counts().reset_index()
fig, ax = plt.subplots(figsize=(15,5))

ax.bar(_['index'], _['unpaid_product_cvart'], tick_label=_['index'])
ax.set(xlabel='число неоплаченных товаров в корзине', ylabel='количество записей', title='Распределение числа неоплаченных товаров в корзине за последние 3 месяца')

plt.show()

# %% [markdown]
# #### service_error

# %%
_  = df_mf['service_error'].value_counts().reset_index()
fig, ax = plt.subplots(figsize=(15,5))

ax.bar(_['index'], _['service_error'], tick_label=_['index'])
ax.set(xlabel='число сбоев', ylabel='количество записей', title='Распределение числа сбоев во время посещения сайта пользователем')

plt.show()

# %% [markdown]
# #### page_per_visit

# %%
_  = df_mf['page_per_visit'].value_counts().reset_index()
fig, ax = plt.subplots(figsize=(15,5))

ax.bar(_['index'], _['page_per_visit'], tick_label=_['index'])
ax.set(xlabel='среднее количество страниц', ylabel='количество записей', title='Распределение среднего количества страниц')

plt.show()

# %% [markdown]
# #### buying_activity

# %%
_ = df_mf['buying_activity'].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(15,5))

ax.pie(_['buying_activity'], labels=_['index'], autopct='%1.1f%%')
ax.set(xlabel='', ylabel='', title='Круговая диаграмма покупательской активности')

plt.show()

# %% [markdown]
# #### type_service

# %%
_ = df_mf['type_service'].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(15,5))

ax.pie(_['type_service'], labels=_['index'], autopct='%1.1f%%')
ax.set(xlabel='', ylabel='', title='Круговая диаграмма типа сервиса')

plt.show()

# %% [markdown]
# #### allow_reporting

# %%
_ = df_mf['allow_reporting'].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(15,5))

ax.pie(_['allow_reporting'], labels=_['index'], autopct='%1.1f%%')
ax.set(xlabel='', ylabel='', title='Круговая диаграмма согласия на дополнительные предложения')

plt.show()

# %% [markdown]
# #### popular_category

# %%
_ = df_mf['popular_category'].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(15,5))

ax.pie(_['popular_category'], labels=_['index'], autopct='%1.1f%%')
ax.set(xlabel='', ylabel='', title='Круговая диаграмма самой популярной категории товаров у покупателя за последние 6 месяцев')

plt.show()

# %% [markdown]
# ### market_money

# %%
df_mm.describe()
# Out:
#               id    revenue
# count   3,900.00   3,900.00
# mean  215,997.50   5,025.70
# std       375.33   1,777.70
# min   215,348.00       0.00
# 25%   215,672.75   4,590.15
# 50%   215,997.50   4,957.50
# 75%   216,322.25   5,363.00
# max   216,647.00 106,862.20

# %%
df_mm.describe(include='object')
# Out:
#                      period
# count                  3900
# unique                    3
# top     препредыдущий_месяц
# freq                   1300

# %% [markdown]
# #### revenue

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.boxplot(df_mm['revenue'], vert=False)
ax.set(xlabel='', ylabel='', title='')

plt.show()

# %%
# в данных имеется аномалия, её нужно заменить на медианное значение 
display(df_mm[df_mm['revenue'] == df_mm['revenue'].max()])
df_mm.loc[df_mm['revenue'] == df_mm['revenue'].max(), 'revenue'] = df_mm['revenue'].median()
df_mm.iloc[98]
# Out:
#         id         period    revenue
# 98  215380  текущий_месяц 106,862.20
# id                215380
# period     текущий_месяц
# revenue         4,957.50
# Name: 98, dtype: object

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.boxplot(df_mm['revenue'], vert=False)
ax.set(xlabel='сумма выручки за период', ylabel='item', title='сумма выручки за орпеделённый период')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.hist(df_mm['revenue'], bins=25, rwidth=0.8)
ax.set(xlabel='сумма выручки за период', ylabel='количество записи', title='Распределение суммы выручки за орпеделённый период')

plt.show()

# %% [markdown]
# #### period

# %%
_ = df_mm['period'].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(15,5))

ax.pie(_['period'], labels=_['index'], autopct='%1.1f%%')
ax.set(xlabel='', ylabel='', title='название периода, во время которого зафиксирована выручка')

plt.show()

# %% [markdown]
# ### market_time

# %%
df_mt.describe()
# Out:
#               id      min
# count   2,600.00 2,600.00
# mean  215,997.50    13.34
# std       375.35     4.08
# min   215,348.00     4.00
# 25%   215,672.75    10.00
# 50%   215,997.50    13.00
# 75%   216,322.25    16.00
# max   216,647.00    23.00

# %%
df_mt.describe(include='object')
# Out:
#                   period
# count               2600
# unique                 2
# top     предыдущий_месяц
# freq                1300

# %% [markdown]
# #### min

# %%
_  = df_mt['min'].value_counts().reset_index()
fig, ax = plt.subplots(figsize=(15,5))

ax.bar(_['index'], _['min'], tick_label=_['index'])
ax.set(xlabel='значение времени, проведённого на сайте, в минутах', ylabel='количество записей', title='Распределение значения времени, проведённого на сайте, в минутах')

plt.show()

# %% [markdown]
# #### period

# %%
_ = df_mt['period'].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(15,5))

ax.pie(_['period'], labels=_['index'], autopct='%1.1f%%')
ax.set(xlabel='', ylabel='', title='название периода, во время которого зафиксировано общее время')

plt.show()

# %% [markdown]
# ### money

# %%
df_m.describe()
# Out:
#               id   profit
# count   1,300.00 1,300.00
# mean  215,997.50     4.00
# std       375.42     1.01
# min   215,348.00     0.86
# 25%   215,672.75     3.30
# 50%   215,997.50     4.04
# 75%   216,322.25     4.67
# max   216,647.00     7.43

# %% [markdown]
# #### profit

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.boxplot(df_m['profit'], vert=False)
ax.set(xlabel='прибыль', ylabel='item', title='значение прибыли')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.hist(df_m['profit'], bins=20, rwidth=0.8)
ax.set(xlabel='прибыль', ylabel='количество записей', title='Распределение значения прибыли')

plt.show()

# %% [markdown]
# ### Отбор клиентов с покупательской активностью не менее трёх месяцев

# %%
display(df_m.shape)
display(df_m[df_m['profit'] > 0].shape)
# Out:
# (1300, 2)
# (1300, 2)

# %% [markdown]
# 1300 уникальных пользователей на данный момент существует в базе, которые релевантны.
# Посмотрим на данные других датасетов.

# %%
display(len(df_mf['id'].unique()),
len(df_mm['id'].unique()),
len(df_mt['id'].unique()))
# Out:
# 1300
# 1300
# 1300

# %% [markdown]
# Проверка показала, что данные во всех датасетах акутальны.

# %% [markdown]
# **Промежуточный вывод:**
#
# По результатам проведения исследовательского анализа:
#
# - визуализированны количественные данные датасета `df_mf`.
# - визуализированны категориальные данные датасета `df_mf`.
# - проведён исследовательский анализ датасета `df_mm`.
# - проведён исследовательский анализ датасета `df_mt`.
# - проведён исследовательский анализ датасета `df_m`.
# - проверенные данные на актуальность.

# %% [markdown]
# ## Объединение таблиц

# %%
# преобразование df_mm
a1 = df_mm[df_mm['period'] == 'препредыдущий_месяц'].drop('period', axis=1)
a1.columns = ['id', 'prev_prev_month_revenue']

a2 = df_mm[df_mm['period'] == 'предыдущий_месяц'].drop('period', axis=1)
a2.columns = ['id', 'prev_month_revenue']

a3 = df_mm[df_mm['period'] == 'текущий_месяц'].drop('period', axis=1)
a3.columns = ['id', 'cur_month_revenue']

a = a1.merge(right=a2, on='id')
a = a.merge(right=a3, on='id')
a.head()
# Out:
#        id  prev_prev_month_revenue  prev_month_revenue  cur_month_revenue
# 0  215348                     0.00                0.00           3,293.10
# 1  215349                 4,472.00            5,216.00           4,971.60
# 2  215350                 4,826.00            5,457.50           5,058.40
# 3  215351                 4,793.00            6,158.00           6,610.40
# 4  215352                 4,594.00            5,807.50           5,872.50

# %%
# преобразование df_mt
b1 = df_mt[df_mt['period'] == 'предыдущий_месяц'].drop('period', axis=1)
b1.columns = ['id', 'prev_month_min']

b2 = df_mt[df_mt['period'] == 'текущий_месяц'].drop('period', axis=1)
b2.columns = ['id', 'cur_month_min']

b = b1.merge(right=b2, on='id')
b.head()
# Out:
#        id  prev_month_min  cur_month_min
# 0  215348              13             14
# 1  215349              12             10
# 2  215350               8             13
# 3  215351              11             13
# 4  215352               8             11

# %%
df = df_mf.merge(right=a, on='id')
df = df.merge(right=b, on='id')

# %%
df = df.drop('id', axis=1)

# %%
df['prev_month_revenue']
# Out:
# 0          0.00
# 1      5,216.00
# 2      5,457.50
# 3      6,158.00
# 4      5,807.50
#          ...
# 1295   3,664.00
# 1296   4,729.00
# 1297   5,160.00
# 1298   4,923.00
# 1299   4,720.00
# Name: prev_month_revenue, Length: 1300, dtype: float64

# %%
# удаление из датасета неактивных пользователей
df = df.query('not(prev_prev_month_revenue == 0 or prev_month_revenue == 0 or cur_month_revenue == 0)')

# %%
df.head()
# Out:
#   buying_activity type_service allow_reporting  market_active_6_month  \
# 1       Снизилась      премиум              да                   4.40
# 2       Снизилась     стандарт             нет                   4.90
# 3       Снизилась     стандарт              да                   3.20
# 4       Снизилась     стандарт             нет                   5.10
# 5       Снизилась     стандарт              да                   3.30
#
#    market_active_current_month  duration  promotional_purchases  \
# 1                            4       819                   0.75
# 2                            3       539                   0.14
# 3                            5       896                   0.99
# 4                            3      1064                   0.94
# 5                            4       762                   0.26
#
#     popular_category  mean_views_category_per_visit  unpaid_product_cvart  \
# 1   Товары для детей                              4                     4
# ...

# %% [markdown]
# **Промежуточный вывод:**
#
# После некоторых преобразований данные были успешно объединены в один датафрейм.

# %% [markdown]
# ## корреляционный анализ признаков в датасете df

# %%
_ = df.phik_matrix(interval_cols=['market_active_6_month', 'duration', 'promotional_purchases', 'prev_prev_month_revenue', 'prev_month_revenue', 'cur_month_revenue'],)
fig, ax = plt.subplots(figsize=(11, 11))
sns.heatmap(_, annot=True)
plt.show()

# %% [markdown]
# **Промежуточный вывод:**
#
# Наиболее значимый показатель корреляции существует между `prev_month_revenue` и `cur_month_revenue`, но это закономерно так как покупателям свойственно последовательное поведение при покупках.

# %% [markdown]
# ## Применение пайплайнов

# %%
RANDOM_STATE = 1337

# %%
y = df['buying_activity']
X = df.drop('buying_activity', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=RANDOM_STATE)

# %%
le = LabelEncoder()

le.fit(y_train)
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
ohe_col = ['popular_category']
ord_col = ['type_service', 'allow_reporting']
num_col = ['market_active_6_month', 'market_active_current_month', 'duration', 'promotional_purchases', 'mean_views_category_per_visit', 'unpaid_product_cvart', 'service_error', 'page_per_visit', 'prev_prev_month_revenue', 'prev_month_revenue', 'cur_month_revenue', 'prev_month_min', 'cur_month_min']

# %%
ohe_pipe = Pipeline(
    [
        (
            'simpleImputer_ohe', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe', 
            OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)
        )
    ]
)

ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',  
            OrdinalEncoder(
                categories=[
                    ['стандарт', 'премиум'], 
                    ['нет', 'да'],
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
) 


data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_col),
        ('ord', ord_pipe, ord_col),
        ('num', StandardScaler(), num_col)
    ], 
    remainder='passthrough'
)

# %%
pipe_final = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
    ]
)

# %%
param_grid=[
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE)],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough'],
    },
    {
        'models': [SVC(random_state=RANDOM_STATE, probability=True)],
        'models__kernel': ['sigmoid', 'linear', 'rbf', 'poly'],
        'models__degree': range(1, 20),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough'],
    },
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(1,100),
        'models__metric': ['euclidean', 'cityblock'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough'],
    },
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 10),
        'models__min_samples_leaf': range(1, 10), 
        'models__min_samples_split': range(2, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough'],
    }
]

# %% [markdown]
# Для оценки качества модели нужно использовать `roc_auc_score` так как значения целевого признака не сбалансированны.

# %%
rs = RandomizedSearchCV(
    pipe_final,
    param_grid,
    scoring='roc_auc',
    n_jobs=-1,
    cv=5,
    n_iter=500,
    random_state=RANDOM_STATE
)

# %%
rs.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %%
print(f'Лучшие харктеристики после проведения обучения разных моделей и гиперпараметров:')
display(rs.best_params_)
print(f'Лучшая оенка модели на тренировочныч данных: {rs.best_score_}')
# Out:
# Лучшие харктеристики после проведения обучения разных моделей и гиперпараметров:
# {'preprocessor__num': StandardScaler(),
#  'models__n_neighbors': 42,
#  'models__metric': 'cityblock',
#  'models': KNeighborsClassifier()}
# Лучшая оенка модели на тренировочныч данных: 0.9210538058719877

# %%
# отбор лучшей модели классификации
rs.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['popular_category']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
# ...

# %%
y_pred = rs.predict_proba(X_test)

# %%
score = roc_auc_score(y_test, y_pred[:,1])

# %%
print(f'Оценка классификации модели на тестовых данных: {score}')
# Out:
# Оценка классификации модели на тестовых данных: 0.9028847696998877

# %% [markdown]
# **Промежуточный вывод:**
#
# По резултатам использования пайплайнов можно выделить несоклько моментов:
# - изначальный датасет был разделён на тренировочную выборку и тестовую с учётом баланса значений целевого признака.
# - закодированы значения целевого признака для упрощения работы.
# - сформированн пайплайн для подготовки данных для обучения модели, и для самой модели.
# - Был прописан словарь с гиперпараметрами для четырёх моделей машинного обучения.
# - Проведено обучение различных моделей на различных парметрах и способах обработки данных с помощью `RandomizedSearchCV`.
# - Получены лучшие параметры и лучшая модель.
# - Значение roc_auc_score на тренировочной и тестовой выборке почти не отличается и равно примерно 0.9.

# %% [markdown]
# ## Анализ важности признаков

# %%
X_train_prep = data_preprocessor.fit_transform(X_train)
X_test_prep = data_preprocessor.transform(X_test)

# %%
columns = [
'Категория_Косметика и аксесуары',
'Категория_Кухонная посуда',
'Категория_Мелкая бытовая техника и электроника',
'Категория_Техника для красоты и здоровья',
'Категория_Товары для детей',
'тип_сервиса',
'разрешить_сообщать',
'Маркет_актив_6_мес',
'Маркет_актив_тек_мес',
'Длительность',
'доля акционных покупок',
'среднее количество просм. категорий за визит',
'количество товаров в корзине',
'количество ошибок сервиса',
'страницы за визит',
'прибыль за предпедыдущий месяц',
'прибыль за педыдущий месяц',
'прибыль за текущий месяц',
'проведённое время на сайте пред. месяц',
'проведённое время на сайте тек. месяц',
]

# %%
df_X_train_prep = pd.DataFrame(X_train_prep, columns=columns)
df_X_test_prep = pd.DataFrame(X_test_prep, columns=columns)

# %%
model = rs.best_estimator_['models'].fit(X_train_prep, y_train)

# %%
# Для оценки важности признаков будет использована столбчатая диаграмма общего вклада признаков в прогнозы модели.
fig, ax = plt.subplots(figsize=(15,5))
explainer = shap.KernelExplainer(lambda x: model.predict_proba(x)[:, 1], shap.sample(df_X_train_prep, 10))
shap_values = explainer(shap.sample(df_X_test_prep, 10))
shap.plots.bar(shap_values, max_display=20, ax=ax, show=False)
ax.set(xlabel='значение коэффициента важности признака', ylabel='Наименование признака', title='График оценки важности признаков общего вклада в прогнозы модели')
plt.show()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# **Промежуточный вывод:**
#
# - Для модели мало значимы признаки:
#
#     - "популярная категория товаров у покупателя",
#
#     - "уровень сервиса",
#
#     - "Согласие на дополнительные предложения",
#
#     - "Ошибка сервиса",
#
#     - "данные о выручке магазина за текущий и предыдущий месяц".
#
# - На целевой признак сильнее всего влияют:
#
#     - "проведённое время в минутах на сайте в текущем месяце",
#
#     - "среднее количество страниц, которые просмотрел покупатель за один визит на сайт",
#
#     - "среднее колисество категорий просмотренное за визит на сайт",
#
#     - "значение числа рассылок, звонков, показов рекламы и прочего, кот. приходилось на клиента за последние 6 месяцев",
#
#     - "значение времени, проведённого на сайте, в минутах в предыдущем месяце".
#
# - В итоге на принятие решения модели, снизилась ли активность пользователей, влияет проведённое время пользователем на сайте, количество просмотренных категорий за визит, количество просмотренных страниц за визит. Если обобщить, то активность пользователя в будущем зависит от текущей и прошлой активности пользователя.

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# Выделим сегмент покупателей, которые покупают только технику, то есть товары с длинным жизненным циклом.

# %%
df_tech = df[df['popular_category'].isin(['Техника для красоты и здоровья', 'Мелкая бытовая техника и электроника'])]
df_tech.sample(5)
# Out:
#       buying_activity type_service allow_reporting  market_active_6_month  \
# 17          Снизилась     стандарт              да                   3.90
# 542   Прежний уровень     стандарт              да                   4.40
# 640   Прежний уровень     стандарт              да                   4.40
# 1038  Прежний уровень     стандарт              да                   4.30
# 729   Прежний уровень      премиум              да                   4.90
#
#       market_active_current_month  duration  promotional_purchases  \
# 17                              4       167                   0.95
# 542                             5       870                   0.30
# 640                             3       910                   0.11
# 1038                            4       661                   0.17
# 729                             4       763                   0.25
#
#                           popular_category  mean_views_category_per_visit  \
# ...

# %%
_ = df_tech['buying_activity'].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(15,5))

ax.pie(_['buying_activity'], labels=_['index'], autopct='%1.1f%%')
ax.set(xlabel='', ylabel='', title='диаграмма покупательской активности')

plt.show()

# %%
df_tech_c = df_tech[df_tech['buying_activity'] == 'Прежний уровень']
df_tech_d = df_tech[df_tech['buying_activity'] == 'Снизилась']

# %%
c_ = df_tech_c['type_service'].value_counts().reset_index()
d_ = df_tech_d['type_service'].value_counts().reset_index()

fig, ax = plt.subplots(1, 2, figsize=(15,5))
fig.suptitle('диаграмма уровня аккаунта пользователя')

ax[0].pie(c_['type_service'], labels=c_['index'], autopct='%1.1f%%')
ax[0].set(xlabel='', ylabel='', title='прежний уровень')

ax[1].pie(d_['type_service'], labels=d_['index'], autopct='%1.1f%%')
ax[1].set(xlabel='', ylabel='', title='снизилась')

plt.show()

# %%
c_ = df_tech_c['prev_month_min']
d_ = df_tech_d['prev_month_min']

fig, ax = plt.subplots(figsize=(15,5))
fig.suptitle('проведённое время в минутах на сайте в предыдущем месяце')

ax.hist(c_, bins=10, rwidth=0.8, label='прежний уровень')
ax.set(xlabel='время', ylabel='количество записей')

ax.hist(d_, bins=10, rwidth=0.8,label='снизилась')
ax.set(xlabel='время', ylabel='количество записей')

ax.legend()
plt.show()

# %%
c_ = df_tech_c['cur_month_min']
d_ = df_tech_d['cur_month_min']

fig, ax = plt.subplots(figsize=(15,5))
fig.suptitle('проведённое время в минутах на сайте в текущем месяце')

ax.hist(c_, bins=10, rwidth=0.8, label='прежний уровень')
ax.set(xlabel='время', ylabel='количество записей')

ax.hist(d_, bins=10, rwidth=0.8, label='снизилась')
ax.set(xlabel='время', ylabel='количество записей')

ax.legend()
plt.show()

# %%
c_ = df_tech_c['mean_views_category_per_visit'].value_counts().reset_index()
d_ = df_tech_d['mean_views_category_per_visit'].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(15,5))
fig.suptitle('среднее количество страниц, которые просмотрел покупатель за один визит на сайт')

ax.bar(c_['index'], c_['mean_views_category_per_visit'], label='прежний уровень')
ax.set(xlabel='', ylabel='количество записей')

ax.bar(d_['index'], d_['mean_views_category_per_visit'], label='снизилась')
ax.set(xlabel='', ylabel='количество записей')

ax.legend()
plt.show()

# %%
c_ = df_tech_c['market_active_6_month']
d_ = df_tech_d['market_active_6_month']

fig, ax = plt.subplots(figsize=(15,5))
fig.suptitle('значение числа рассылок, звонков, показов рекламы и прочего, кот. приходилось на клиента за последние 6 месяцев')

ax.hist(c_, bins=10, rwidth=0.8, label='прежний уровень')
ax.set(xlabel='число', ylabel='количество записей')

ax.hist(d_, bins=10, rwidth=0.8, label='снизилась')
ax.set(xlabel='число', ylabel='количество записей')

ax.legend()
plt.show()

# %% [markdown]
# **предложения по работе с сегментом для увеличения покупательской активности**
# - На одной странице можно размещать больше карточек, чтобы пользователь дольше смотрел товары перед обновлением сайта.
# - Цену на премиум аккаунт можно снизить, так как он особо не влияет на поведение пользователя. Возможно стоит пересмотреть концепцию привилегий премиум аккаунта.
# - Число рассылок, звонков, показов рекламы и подобных однозначно нужно увеличить.

# %% [markdown]
# **Промежуточный вывод:**
# - Для анализа был взят сегмент покупателей, которые покупают только технику, то есть товары с длинным жизненным циклом.
# - Заказчикам нужно пересмотреть концепцию премиум аккаунта, так как данные показали, что он не влияет на поведение пользователей.
# - Ещё нужно увеличить количетво карточек товаров на одной странцие, чтобы человек меньше обновлял сайт.
# - Также увеличить надо рекламные акции, потому что это влияет на активность пользователей.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# - Задача звучит так: отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
# - Исходные данные содержат 4 датасета о поведении пользователя и его покупках, о выручке магазина за 3 месяца, о проведённом времени пользователя на сайте и о среднемесячной прибыли магазина с покупателей за 3 месяца.
# - Для поиска лучшей модели был создан пайплайн подготовки данных и обучения модели. Далее был использован инструмент для автоматизированного перебора гиперпараметров, который в итоге нашёл лучшее решение.
# - Выбранная модель - модель k-ближайших соседей с параметром ближайших соседей равным 43.
# - Для сегмента пользователей, которые покупают преимущественно технику:
#     + нужно увеличить количество рекламных акций для пользователей
#     + нужно увеличить количество карточек товаров на одной странице
#     + нужно пересмотреть концепцию премиум аккаунта
